# %%
import numpy as np
import matplotlib.pyplot as plt
from time import process_time

# %%
def rosenbrock(x1,x2):
    return (1 - x1)**2 + 100*((x2 - (x1**2))**2)

def himmelblau(x1,x2):
    return (x1**2 + x2 - 11)**2 + (x1 + x2**2 - 7)**2

def grad_rosenbrock(x1,x2):
    grad1 = -2*(1-x1) - 400*x1*(x2 - x1**2)
    grad2 = 200*(x2 - x1**2)
    return grad1, grad2

def grad_himmelblau(x1,x2):
    grad1 = 4*x1*(x1**2 +x2 - 11) + 2*(x1 + x2**2 - 7)
    grad2 = 2*(x1**2 + x2 - 11) + 4 * x2 *(x1 + x2**2 - 7)
    return grad1, grad2

# %% [markdown]
# Plotting Rosenbrock's Function:

# %%
x1 = np.linspace(-2, 2, 500)
x2 = np.linspace(-1, 3, 500)
X1, X2 = np.meshgrid(x1, x2)
Z = rosenbrock(X1, X2)

#3D Plot"
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(121, projection='3d')
surf = ax1.plot_surface(X1, X2, Z, cmap='viridis', edgecolor='none', alpha=0.9)
ax1.set_title("3D Surface Plot of Rosenbrock's Function")
ax1.set_xlabel('$x_1$')
ax1.set_ylabel('$x_2$')
ax1.set_zlabel('$f(x_1, x_2)$')
fig.colorbar(surf, ax=ax1, shrink=0.5, aspect=10)

# Contour plot
ax2 = fig.add_subplot(122)
contour = ax2.contour(X1, X2, Z, levels=50, cmap='viridis')
ax2.set_title("Contour Plot of Rosenbrock's Function")
ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$x_2$')
fig.colorbar(contour, ax=ax2, shrink=0.7, aspect=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Plotting Himmelblau's Function:

# %%
x1 = np.linspace(-6, 6, 500)
x2 = np.linspace(-6, 6, 500)
X1, X2 = np.meshgrid(x1, x2)
Z = himmelblau(X1, X2)

# Plot Himmelblau's function in 3D
fig = plt.figure(figsize=(12, 6))

# 3D Surface plot
ax1 = fig.add_subplot(121, projection='3d')
surf = ax1.plot_surface(X1, X2, Z, cmap='plasma', edgecolor='none', alpha=0.9)
ax1.set_title("3D Surface Plot of Himmelblau's Function")
ax1.set_xlabel('$x_1$')
ax1.set_ylabel('$x_2$')
ax1.set_zlabel('$f(x_1, x_2)$')
fig.colorbar(surf, ax=ax1, shrink=0.5, aspect=10)

# Contour plot
ax2 = fig.add_subplot(122)
contour = ax2.contour(X1, X2, Z, levels=50, cmap='plasma')
ax2.set_title("Contour Plot of Himmelblau's Function")
ax2.set_xlabel('$x_1$')
ax2.set_ylabel('$x_2$')
fig.colorbar(contour, ax=ax2, shrink=0.7, aspect=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Steepest Descent (Constant) Algorithm

# %%
def steepest_descent_constant(x0, grad_func, step_size, tol = 1e-10):
    t1_start = process_time()
    x = x0
    iter = 0
    import numpy as np
    while np.linalg.norm(grad_func(x[0],x[1])) > tol:
        x = x - step_size * np.array(grad_func(x[0],x[1]))
        iter += 1
    print('Iterations:', iter)
    t1_stop = process_time()
    print("CPU_time:",t1_stop-t1_start)
    return x

# %%
x0 = np.array([0, 0])

# %%
xpi = np.array([np.pi + 1, np.pi - 1])

# %% [markdown]
# Applying the constant Steepest Descent Algorithm to the functions

# %%
step_size = 0.0005
tolerance = 1e-11
result = steepest_descent_constant(x0, grad_rosenbrock, step_size, tolerance)
print(result)
print("The value of the function is:", rosenbrock(result[0], result[1]))
# Out:
# Iterations: 120271
# CPU_time: 1.9995992429999996
# [1. 1.]
# The value of the function is: 1.2516258105461727e-22

# %%
step_size = 0.005
tolerance = 1e-11
result = steepest_descent_constant(xpi, grad_rosenbrock, step_size, tolerance)
print(result)
print("The value of the function is:", rosenbrock(result[0], result[1]))
# Out:
# Iterations: 6
# CPU_time: 0.0035173349999997328
# [inf inf]
# The value of the function is: nan
# <ipython-input-2-23943fa8c31c>:8: RuntimeWarning: overflow encountered in scalar power
#   grad1 = -2*(1-x1) - 400*x1*(x2 - x1**2)
# <ipython-input-2-23943fa8c31c>:9: RuntimeWarning: overflow encountered in scalar power
#   grad2 = 200*(x2 - x1**2)
# <ipython-input-2-23943fa8c31c>:8: RuntimeWarning: invalid value encountered in scalar subtract
#   grad1 = -2*(1-x1) - 400*x1*(x2 - x1**2)
# <ipython-input-2-23943fa8c31c>:9: RuntimeWarning: invalid value encountered in scalar subtract
#   grad2 = 200*(x2 - x1**2)
# <ipython-input-2-23943fa8c31c>:2: RuntimeWarning: invalid value encountered in scalar subtract
#   return (1 - x1)**2 + 100*((x2 - (x1**2))**2)

# %%
step_size = 0.00005
tolerance = 1e-11
result = steepest_descent_constant(xpi, grad_rosenbrock, step_size, tolerance)
print(result)
print("The value of the function is:", rosenbrock(result[0], result[1]))
# Out:
# Iterations: 1296467
# CPU_time: 16.872371858999998
# [1. 1.]
# The value of the function is: 1.1861275100010136e-22

# %%
step_size = 0.0005
tolerance = 1e-11
result = steepest_descent_constant(x0, grad_himmelblau, step_size, tolerance)
print(result)
print("The value of the function is:", himmelblau(result[0], result[1]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6ab6aa133c3> in <cell line: 3>()
#       1 step_size = 0.0005
#       2 tolerance = 1e-11
# ----> 3 result = steepest_descent_constant(x0, grad_himmelblau, step_size, tolerance)
#       4 print(result)
#       5 print("The value of the function is:", himmelblau(result[0], result[1]))
#
# NameError: name 'steepest_descent_constant' is not defined

# %%
step_size = 0.0005
tolerance = 1e-11
result = steepest_descent_constant(xpi, grad_himmelblau, step_size, tolerance)
print(result)
print("The value of the function is:", himmelblau(result[0], result[1]))
# Out:
# Iterations: 2093
# CPU_time: 0.026307490000000655
# [3. 2.]
# The value of the function is: 1.9106968430921918e-24

# %% [markdown]
# Armijo's Step-Size Function

# %%
def armijo_stepsize(f, grad_f, x, d, delta=0.01, beta=0.5, max_iter=50):
    gamma = 0.001
    t = -gamma * (np.dot(np.array(grad_f(x[0], x[1])), d)/ (np.linalg.norm(d)**2))
    grad_val = grad_f(x[0], x[1])
    for _ in range(max_iter):
        new_x = x + t * d
        if f(*new_x) <= f(*x) + delta * t * np.dot(grad_val, d):
            return t
        t *= beta  # Reduce step size
        if t < 1e-10:  # Prevents infinite loop
            break
    return t

# %% [markdown]
# Steepest Descent Algorithm With Armijo's Step-Size

# %%
def steepest_descent_armijo(x0, func, grad_func, tol=1e-11, max_iter=100000):
    t2_start = process_time()
    x = np.array(x0, dtype=float)
    for i in range(max_iter):
        grad_val = np.array(grad_func(x[0], x[1]))
        grad_norm = np.linalg.norm(grad_val)
        if grad_norm < tol:
            t2_stop = process_time()
            print(f"Convergence achieved after {i} iterations.")
            print("CPU_time:", t2_stop - t2_start)
            return x
        d = -grad_val
        step_size = armijo_stepsize(func, grad_func, x, d)
        x = x + step_size * d  # Update x
        if np.any(np.abs(x) > 1e3):  # Safeguard against divergence
            t2_stop = process_time()
            print("Divergence detected. Exiting...")
            print("CPU_time:", t2_stop - t2_start)
            return None
    print("Maximum iterations reached. Exiting...")
    t2_stop = process_time()
    print("CPU_time:",t2_stop-t2_start)
    return None

# %% [markdown]
# Applying the Steepest Descent Algorithm with Armijo's Step-Size to the functions

# %%
print("For x0 = [0, 0]:")
rosen_result_x0 = steepest_descent_armijo(x0, rosenbrock, grad_rosenbrock)
print("Rosenbrock minimizer (x0):", rosen_result_x0)
print("The value of the function is:", rosenbrock(rosen_result_x0[0], rosen_result_x0[1]))
# Out:
# For x0 = [0, 0]:
# Convergence achieved after 60128 iterations.
# CPU_time: 2.0880128140000007
# Rosenbrock minimizer (x0): [1. 1.]
# The value of the function is: 1.2513081007608995e-22

# %%
print("For xpi = [pi + 1, pi - 1]:")
rosen_result_xpi = steepest_descent_armijo(xpi, rosenbrock, grad_rosenbrock)
print("Rosenbrock minimizer (xpi):", rosen_result_xpi)
print("The value of the function is:", rosenbrock(rosen_result_xpi[0], rosen_result_xpi[1]))
# Out:
# For xpi = [pi + 1, pi - 1]:
# Convergence achieved after 62175 iterations.
# CPU_time: 2.4028663339999987
# Rosenbrock minimizer (xpi): [1. 1.]
# The value of the function is: 1.2513329194343134e-22

# %%
print("For x0 = [0, 0]:")
himmel_result_x0 = steepest_descent_armijo(x0, himmelblau, grad_himmelblau)
print("Himmelblau minimizer:", himmel_result_x0)
print("The value of the function is:", himmelblau(himmel_result_x0[0], himmel_result_x0[1]))
# Out:
# For x0 = [0, 0]:
# Convergence achieved after 1114 iterations.
# CPU_time: 0.05424672200000025
# Himmelblau minimizer: [3. 2.]
# The value of the function is: 1.90051738197122e-24

# %%
print("For xpi = [pi + 1, pi - 1]:")
himmel_result_xpi = steepest_descent_armijo(xpi, himmelblau, grad_himmelblau)
print("Himmelblau minimizer:", himmel_result_xpi)
print("The value of the function is:", himmelblau(himmel_result_xpi[0], himmel_result_xpi[1]))
# Out:
# For xpi = [pi + 1, pi - 1]:
# Convergence achieved after 1039 iterations.
# CPU_time: 0.04716951199999997
# Himmelblau minimizer: [3. 2.]
# The value of the function is: 1.939894162916232e-24

# %% [markdown]
# Generating the other Minimas

# %%
def find_multiple_minima(func, grad_func, bounds, num_points=100):
    minima = []
    starting_points = np.random.uniform(bounds[0], bounds[1], size=(num_points, 2))
    for x0 in starting_points:
        result = steepest_descent_armijo(x0, func, grad_func)
        if result is not None:
            # Rounding the results to avoid duplicates caused by floating-point precision
            rounded_result = np.round(result, decimals=4)
            if not any(np.allclose(rounded_result, m, atol=1e-4) for m in minima):
                minima.append(rounded_result)
    return minima

# Define bounds for starting points
bounds = [-10, 10]

himmel_minima = find_multiple_minima(himmelblau, grad_himmelblau, bounds)

print("Himmelblau's function minima:")
for minimum in himmel_minima:
    print(minimum)
# Out:
# Convergence achieved after 1002 iterations.
# CPU_time: 0.05191451700000016
# Convergence achieved after 1140 iterations.
# CPU_time: 0.049885425999999455
# Convergence achieved after 479 iterations.
# CPU_time: 0.018245144999998075
# Convergence achieved after 833 iterations.
# CPU_time: 0.03347428800000074
# Convergence achieved after 976 iterations.
# CPU_time: 0.036845867000000254
# Convergence achieved after 480 iterations.
# CPU_time: 0.020448335000001094
# Convergence achieved after 1094 iterations.
# CPU_time: 0.04072823599999964
# Convergence achieved after 407 iterations.
# CPU_time: 0.017533934999999445
# Convergence achieved after 394 iterations.
# CPU_time: 0.015553955999997982
# Convergence achieved after 443 iterations.
# CPU_time: 0.017654443000001407
# Convergence achieved after 1149 iterations.
# CPU_time: 0.04853375100000079
# Convergence achieved after 1303 iterations.
# CPU_time: 0.06229230399999963
# Convergence achieved after 1077 iterations.
# CPU_time: 0.044615572000001436
# Convergence achieved after 981 iterations.
# CPU_time: 0.042504440000001864
# Convergence achieved after 1086 iterations.
# CPU_time: 0.04078516999999948
# Convergence achieved after 1048 iterations.
# CPU_time: 0.03852130499999973
# Convergence achieved after 980 iterations.
# CPU_time: 0.03868627199999963
# Convergence achieved after 1084 iterations.
# CPU_time: 0.046385477999997704
# Convergence achieved after 442 iterations.
# CPU_time: 0.016948582999997797
# Convergence achieved after 970 iterations.
# CPU_time: 0.036740404999999754
# Convergence achieved after 411 iterations.
# CPU_time: 0.015257348999998754
# Convergence achieved after 442 iterations.
# CPU_time: 0.018962013999999527
# Convergence achieved after 467 iterations.
# CPU_time: 0.01859248699999938
# Convergence achieved after 978 iterations.
# CPU_time: 0.03598720899999819
# Convergence achieved after 449 iterations.
# CPU_time: 0.017952323999999464
# Convergence achieved after 503 iterations.
# CPU_time: 0.01890506399999836
# Convergence achieved after 438 iterations.
# CPU_time: 0.020585023000002423
# Convergence achieved after 907 iterations.
# CPU_time: 0.03317865200000014
# Convergence achieved after 451 iterations.
# CPU_time: 0.01664390099999835
# Convergence achieved after 452 iterations.
# CPU_time: 0.018166699000001785
# Convergence achieved after 439 iterations.
# CPU_time: 0.019964048999998596
# Convergence achieved after 408 iterations.
# CPU_time: 0.01656532400000188
# Convergence achieved after 490 iterations.
# CPU_time: 0.025550911999999926
# Convergence achieved after 1041 iterations.
# CPU_time: 0.04972555000000156
# Convergence achieved after 397 iterations.
# CPU_time: 0.020823802999998975
# Convergence achieved after 557 iterations.
# CPU_time: 0.02160286999999883
# Convergence achieved after 1087 iterations.
# CPU_time: 0.04264738000000179
# Convergence achieved after 441 iterations.
# CPU_time: 0.01757557799999887
# Convergence achieved after 442 iterations.
# CPU_time: 0.018059684000000686
# Convergence achieved after 404 iterations.
# CPU_time: 0.016523059000000728
# Convergence achieved after 975 iterations.
# CPU_time: 0.03507956800000045
# Convergence achieved after 1228 iterations.
# CPU_time: 0.05089621500000163
# Convergence achieved after 1090 iterations.
# CPU_time: 0.04338954100000336
# Convergence achieved after 442 iterations.
# CPU_time: 0.018143036999997975
# Convergence achieved after 409 iterations.
# CPU_time: 0.015962619999999816
# Convergence achieved after 1087 iterations.
# CPU_time: 0.04205450499999941
# Convergence achieved after 410 iterations.
# CPU_time: 0.014570068000001157
# Convergence achieved after 563 iterations.
# CPU_time: 0.022298532000000648
# Convergence achieved after 1145 iterations.
# CPU_time: 0.04968039299999916
# Convergence achieved after 981 iterations.
# CPU_time: 0.03619523800000124
# Convergence achieved after 409 iterations.
# CPU_time: 0.016051083000000688
# Convergence achieved after 966 iterations.
# CPU_time: 0.03909261700000144
# Convergence achieved after 441 iterations.
# CPU_time: 0.01983474600000079
# Convergence achieved after 476 iterations.
# CPU_time: 0.02007517499999878
# Convergence achieved after 1136 iterations.
# CPU_time: 0.0426404809999994
# Convergence achieved after 956 iterations.
# CPU_time: 0.038210498000001536
# Convergence achieved after 420 iterations.
# CPU_time: 0.01757482700000068
# Convergence achieved after 980 iterations.
# CPU_time: 0.038992251999999894
# Convergence achieved after 407 iterations.
# CPU_time: 0.016418328000000315
# Convergence achieved after 476 iterations.
# CPU_time: 0.01838995999999682
# Convergence achieved after 440 iterations.
# CPU_time: 0.01608631199999877
# Convergence achieved after 388 iterations.
# CPU_time: 0.015898674999998974
# Convergence achieved after 798 iterations.
# CPU_time: 0.03039125799999809
# Convergence achieved after 980 iterations.
# CPU_time: 0.04594663600000004
# Convergence achieved after 1063 iterations.
# CPU_time: 0.04091258400000086
# Convergence achieved after 1200 iterations.
# CPU_time: 0.04495431100000147
# Convergence achieved after 1051 iterations.
# CPU_time: 0.03721037400000071
# Convergence achieved after 978 iterations.
# CPU_time: 0.049520212000000896
# Convergence achieved after 409 iterations.
# CPU_time: 0.01514578199999761
# Convergence achieved after 405 iterations.
# CPU_time: 0.01916336200000046
# Convergence achieved after 442 iterations.
# CPU_time: 0.017341709000000094
# Convergence achieved after 1100 iterations.
# CPU_time: 0.042109061999997976
# Convergence achieved after 409 iterations.
# CPU_time: 0.01937093800000156
# Convergence achieved after 979 iterations.
# CPU_time: 0.036851892000001385
# Convergence achieved after 443 iterations.
# CPU_time: 0.018992301000000822
# Convergence achieved after 439 iterations.
# CPU_time: 0.01842853000000133
# Convergence achieved after 978 iterations.
# CPU_time: 0.056215077999997476
# Convergence achieved after 980 iterations.
# CPU_time: 0.052691084999999305
# Convergence achieved after 1144 iterations.
# CPU_time: 0.04264480099999801
# Convergence achieved after 409 iterations.
# CPU_time: 0.016078140000001184
# Convergence achieved after 979 iterations.
# CPU_time: 0.042658248000002175
# Convergence achieved after 548 iterations.
# CPU_time: 0.02484111600000105
# Convergence achieved after 397 iterations.
# CPU_time: 0.01572518000000045
# Convergence achieved after 405 iterations.
# CPU_time: 0.02174156799999949
# Convergence achieved after 424 iterations.
# CPU_time: 0.016212025999998048
# Convergence achieved after 951 iterations.
# CPU_time: 0.03914570699999942
# Convergence achieved after 1107 iterations.
# CPU_time: 0.04157578600000278
# Convergence achieved after 1074 iterations.
# CPU_time: 0.03859417700000023
# Convergence achieved after 409 iterations.
# CPU_time: 0.020125889999999202
# Convergence achieved after 978 iterations.
# CPU_time: 0.04978800299999975
# Convergence achieved after 1102 iterations.
# CPU_time: 0.042168653999997474
# Convergence achieved after 408 iterations.
# CPU_time: 0.016715780000001956
# Convergence achieved after 951 iterations.
# CPU_time: 0.03659192699999991
# Convergence achieved after 981 iterations.
# CPU_time: 0.03674063099999714
# Convergence achieved after 1334 iterations.
# CPU_time: 0.0497142359999998
# Convergence achieved after 1049 iterations.
# CPU_time: 0.04343692299999802
# Convergence achieved after 388 iterations.
# CPU_time: 0.014338884000000718
# Convergence achieved after 501 iterations.
# CPU_time: 0.017766606000002128
# Convergence achieved after 1199 iterations.
# CPU_time: 0.04462606699999938
# Convergence achieved after 1059 iterations.
# CPU_time: 0.05381939000000102
# Himmelblau's function minima:
# [ 3.5844 -1.8481]
# [3. 2.]
# [-2.8051  3.1313]
# [-3.7793 -3.2832]

# %%
def find_multiple_minima(func, grad_func, bounds, num_points=25):
    minima = []
    starting_points = np.random.uniform(bounds[0], bounds[1], size=(num_points, 2))
    for x0 in starting_points:
        result = steepest_descent_armijo(x0, func, grad_func)
        if result is not None:
            # Round the result to avoid duplicates caused by floating-point precision
            rounded_result = np.round(result, decimals=4)
            if not any(np.allclose(rounded_result, m, atol=1e-4) for m in minima):
                minima.append(rounded_result)
    return minima

# Define bounds for starting points
bounds = [-10, 10]

# Find all minima for Himmelblau's function
rosen_minima = find_multiple_minima(rosenbrock, grad_rosenbrock, bounds)

# Print the results
print("Rosenbrock's function minima:")
for minimum in rosen_minima:
    print(minimum)
# Out:
# Convergence achieved after 69824 iterations.
# CPU_time: 2.9286899270000006
# Convergence achieved after 73089 iterations.
# CPU_time: 2.558050345999998
# Convergence achieved after 60140 iterations.
# CPU_time: 2.079312752
# Convergence achieved after 60143 iterations.
# CPU_time: 2.078129524999998
# Convergence achieved after 67570 iterations.
# CPU_time: 3.0231149090000002
# Convergence achieved after 60359 iterations.
# CPU_time: 2.576792221999998
# Convergence achieved after 60144 iterations.
# CPU_time: 2.1717700330000014
# Convergence achieved after 64961 iterations.
# CPU_time: 2.2378378189999992
# Convergence achieved after 60134 iterations.
# CPU_time: 2.059773915000001
# Convergence achieved after 60009 iterations.
# CPU_time: 2.1004698349999984
# Convergence achieved after 85330 iterations.
# CPU_time: 4.24677655
# Convergence achieved after 60143 iterations.
# CPU_time: 2.107731504
# Convergence achieved after 60138 iterations.
# CPU_time: 2.1054095349999997
# Convergence achieved after 61094 iterations.
# CPU_time: 2.0879989489999957
# Convergence achieved after 60131 iterations.
# CPU_time: 2.086760684000005
# Convergence achieved after 94208 iterations.
# CPU_time: 4.758227364
# Convergence achieved after 60144 iterations.
# CPU_time: 2.043937047
# Convergence achieved after 60141 iterations.
# CPU_time: 2.039083875000003
# Convergence achieved after 72288 iterations.
# CPU_time: 2.567849406999997
# Convergence achieved after 60137 iterations.
# CPU_time: 2.3174538199999972
# Convergence achieved after 60129 iterations.
# CPU_time: 2.923452204
# Convergence achieved after 76006 iterations.
# CPU_time: 2.674931893000007
# Convergence achieved after 64793 iterations.
# CPU_time: 2.2236492260000063
# Convergence achieved after 86662 iterations.
# CPU_time: 3.1635287000000005
# Convergence achieved after 60141 iterations.
# CPU_time: 2.5791152479999937
# Rosenbrock's function minima:
# [1. 1.]
